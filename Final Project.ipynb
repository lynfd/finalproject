# %%
import random

class Dice():
    def __init__(self,input1,input2):
        self.input1=input1
        self.input2=input2
        
    def d20(quantity,modifier):
        ran=random.randrange(1,20)
        print(f'The d20 rolled {ran} with a {modifier} modifier for {ran+modifier} total.')
    
    def d12(quantity,modifier):
        ran=random.randrange(1,12)
        print(f'The d12 rolled {ran} with a {modifier} modifier for {ran+modifier} total.')
    
    def d100(quantity,modifier):
        ran=random.randrange(10,100,10)
        print(f'The d100 rolled {ran} with a {modifier} modifier for {ran+modifier} total.')
    
    def d10(quantity,modifier):
        ran=random.randrange(1,10)
        print(f'The d10 rolled {ran} with a {modifier} modifier for {ran+modifier} total.')
    
    def d8(quantity,modifier):
        ran=random.randrange(1,8)
        print(f'The d8 rolled {ran} with a {modifier} modifier for {ran+modifier} total.')
    
    def d6(quantity,modifier):
        ran=random.randrange(1,6)
        print(f'The d10 rolled {ran} with a {modifier} modifier for {ran+modifier} total.')
    
    def d4(quantity,modifier):
        ran=random.randrange(1,4)
        print(f'The d10 rolled {ran} with a {modifier} modifier for {ran+modifier} total.')
    
while True:
    print("What kind of dice would you like to roll?")
    print("d20  d12  d100  d10  d8  d6  d4")
    print("Enter quit to exit")
    
    choice=input("Enter your choice: ")
    
    if choice.lower()=="d20":
        quantity=int(input("Enter how many times you would like to roll: "))
        modifier=int(input("Enter the modifier you would like to add to the roll: "))
        for q in range(quantity):
            Dice.d20(quantity,modifier)
            
    elif choice.lower()=="d12":
        quantity=int(input("Enter how many times you would like to roll: "))
        modifier=int(input("Enter the modifier you would like to add to the roll: "))
        for q in range(quantity):
            Dice.d12(quantity,modifier)
            
    elif choice.lower()=="d100":
        quantity=int(input("Enter how many times you would like to roll: "))
        modifier=int(input("Enter the modifier you would like to add to the roll: "))
        for q in range(quantity):
            Dice.d100(quantity,modifier)
            
    elif choice.lower()=="d10":
        quantity=int(input("Enter how many times you would like to roll: "))
        modifier=int(input("Enter the modifier you would like to add to the roll: "))
        for q in range(quantity):
            Dice.d10(quantity,modifier)
            
    elif choice.lower()=="d8":
        quantity=int(input("Enter how many times you would like to roll: "))
        modifier=int(input("Enter the modifier you would like to add to the roll: "))
        for q in range(quantity):
            Dice.d8(quantity,modifier)
            
    elif choice.lower()=="d6":
        quantity=int(input("Enter how many times you would like to roll: "))
        modifier=int(input("Enter the modifier you would like to add to the roll: "))
        for q in range(quantity):
            Dice.d6(quantity,modifier)
            
    elif choice.lower()=="d4":
        quantity=int(input("Enter how many times you would like to roll: "))
        modifier=int(input("Enter the modifier you would like to add to the roll: "))
        for q in range(quantity):
            Dice.d4(quantity,modifier)
            
    elif choice.lower()=="quit":
        break
        
    else:
        print("Not a valid input.")
# Out:
# What kind of dice would you like to roll?
# d20  d12  d100  d10  d8  d6  d4
# Enter quit to exit
